# %%
from qiskit import __version__

print(__version__)
# Out:
# 2.3.1

# %%
#Suma de arrays y su media

# %%
import numpy as np

ket0 = np.array([[1],[0]])
ket1 = np.array([[0],[1]])

print((ket0 + ket1)/2)
# Out:
# [[0.5]
#  [0.5]]

# %%
# Suma de matrices. Mismo principio que antes

# %%
M1 = np.array([[1,1], [0,0]])
M2 = np.array([[1,0], [0,1]])

M = (M1 + M2)/2
print(M)
# Out:
# [[1.  0.5]
#  [0.  0.5]]
